# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nu = 1
gamma = 1

rho = np.linspace(0, 1, 100)

MYL_7 = rho * (1 - (nu * gamma * (1 - rho)))
MYL_2 = ((gamma / (rho + gamma - rho * gamma)) - rho * gamma / (rho + gamma - rho * gamma)) * (1 - rho)
HAND2 = gamma / (rho + gamma - rho * gamma)
IRX4 = gamma / (rho + gamma - rho * gamma) - rho * (gamma / (rho + gamma - rho * gamma))
HEY2 = nu * gamma * (1 - rho)
NR2F2 = rho

plt.figure(figsize=(10, 5))  # Adjusting figure size
plt.plot(x, MYL_7, label='MYL7*', color='blue', linewidth=4)
plt.plot(x, MYL_2, label='MYL2*', color='black', linewidth=4)
plt.plot(x, HAND2, label='HAND2*', color='green', linewidth=4)
plt.plot(x, IRX4, label='IRX4*', color='red', linewidth=4)
plt.plot(x, HEY2, label='HEY2*', color='yellow', linestyle='--', linewidth=4)
plt.plot(x, NR2F2, label='NR2F2*', color='orange', linewidth=4)

# Add labels and title
plt.xlabel('RA/ρ')
plt.ylabel('Node Activities (on the Steady State)')
#plt.title('Ra')

plt.xticks(np.arange(0, 1.1, 0.1)) 
plt.yticks(np.arange(0, 1.1, 0.1)) 

# Add a legend

plt.legend(fontsize=12) 
plt.tick_params(axis='both', which='major', labelsize=13) 

#plt.xlim(0, 1.05)  # Set x-axis limits
#plt.ylim(0, 1.05)  # Set y-axis limits
#plt.rc('axes', labelsize=14) 
# Show the plot
plt.grid(True)  # Adding grid for better visualization
plt.savefig('plot.svg', format='svg')
plt.show()
